# %%
#british airlines
   # place
    # time
    # display seat
    # booking seat
    # payment
    # cancellation 
    # refund
class british_airlines:
    def __init__(self):
        print("welcome to british airlines")
        available_options=["place","time","display seat","booking seat","payment","cancellation","refund"]
        Available_options={"for place":f"enter the 'place' below",
        "for time":f"enter the 'time' below",
        "for display seat":f"enter the 'display seat' below",
        "for booking seat":f"enter the 'booking seat' below",
        "for payment":f"enter the 'payment' below",
        "for cancellation" :f"enter the 'cancellation' below",
        "for refund":f"enter the 'refund' below"}
        for i in Available_options.items():    
            print(i)
        selected=input("enter the option")
        while selected not in available_options: 
            if selected in available_options:
                pass
            else:
                 selected=input("enter the option")
                 print("Thanks for choosing.if valid we will proceed next step")

    def place(self):
        print("choose the below place to go : ")
        source="chennai"          
        self.ticket_price={
            'banglore':1200,
            'goa':5000,
            'russia':75000,
            'spain':60000,
            'argentina':35000
        }
        for ticket in self.ticket_price:
            print(ticket)
        self.place=input("enter the place")
        if self.place in self.ticket_price:
            
            print(f"for one trip from {source} to {self.place}:{self.ticket_price[self.place]}")
            self.selected_place=self.ticket_price[self.place]
    def display_seat(self):
        print("to view available seat select below")
        self.seat_capacity={
            'banglore':50,
            'goa':60,
            'russia':70,
            'spain':80,
            'argentina':100
        }
        for seat in self.seat_capacity:
            print(seat)
        self.seat_place=input("enter the seat_place")
        if self.seat_place in self.seat_capacity:
            return(f"{self.seat_place}:{self.seat_capacity[self.seat_place]}seats available!!")
        
    def Booking_seat(self):
   
        
        set=True
        
        while set:
            self.total_seat=list(range(1,101))
            for seat in self.total_seat:
                print(seat,end=" ")
            self.no_ofseat=int(input("enter the seat"))
            self.selected_seats=[]
            for seat in range(self.no_ofseat):
                self.selected_seat=int(input("enter the seat no : "))
                if self.selected_seat in self.total_seat:
                    self.total_seat.remove(self.selected_seat)
                    self.selected_seats.append(self.selected_seat)
               
                else:
                    print("invalid")
                    airlines.display_seat()
            print("total seat still available :",self.total_seat)
            self.selected_seats.sort()
            print(f"your confirmed seat :{self.selected_seats}")
            set=False
        
                
    def payment(self):
        print("available payments!!")
        self.payment_method={'upi': ['paytm', 'gpay', 'phonepe', 'paypal'],
             'card': ['creditcard', 'debitcard'],
             'payment_gateway': 'netbanking' }
        for payment in self.payment_method:
            print(payment)
        card_type=['visa', 'master', 'rupay']
        self.Total_cost = self.selected_place*self.no_ofseat
        print(f"total amount need to pay{self.Total_cost}select the payment mode below")
        Mode_payment=input("enter the mode of payment")#upi
        if Mode_payment in self.payment_method:
            print(f"{self.payment_method[Mode_payment]}enter selective choice")
            mode_payment=input("enter the mode of payment")
            if mode_payment in self.payment_method[Mode_payment]:
                    if mode_payment == 'creditcard' or mode_payment=='debitcard':
                        print("enter the card details below")
                        cardnumber=input("enter the card number :")
                        password=input("enter the password :")
                        self.amount=float(input("enter the amount"))23999
                        if self.Total_cost-self.amount==0:
                            print(f"payement successfull,booked seats :{self.selected_seats} Thanks for booking")
                        else:
                           needtopay=self.Total_cost-self.amount
                           print(f"balance need to pay{needtopay}")
                    elif mode_payment in ['paytm', 'gpay', 'phonepe', 'paypal']:
                        print("do payment above number :9123517653")
                        self.amount=float(input("enter the amount")) 
                        if self.Total_cost-self.amount==0:
                            print(f"payement successfull,booked seats :{self.selected_seats} Thanks for booking")
                        else:
                           needtopay=self.Total_cost-self.amount
                           print(f"balance need to pay{needtopay}")
        else:
            print("invalid mode of payment")
airlines=british_airlines() 
airlines.place()
airlines.display_seat()
airlines.Booking_seat()
airlines.payment()
